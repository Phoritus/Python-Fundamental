# %%
import numpy as np

# %%
c = np.array([
	[101,'Mira'],
	[102,'Abdul'],
	[103,'Andrea']
])

d = np.array([
	[101,250.50,'2023-08-01'],
	[102,150.50,'2023-08-02'],
	[103,300.75,'2023-08-01']
])

# %%
np.hstack((c,d))
# Out:
# array([['101', 'Mira', '101', '250.5', '2023-08-01'],
#        ['102', 'Abdul', '102', '150.5', '2023-08-02'],
#        ['103', 'Andrea', '103', '300.75', '2023-08-01']], dtype='<U32')

# %%
c
# Out:
# array([['101', 'Mira'],
#        ['102', 'Abdul'],
#        ['103', 'Andrea']], dtype='<U21')

# %%
e = np.array([
	[104,'Venguard'],
	[105,'John'],
	[106,'Karaoke']
])

# %%
np.vstack((c,e))
# Out:
# array([['101', 'Mira'],
#        ['102', 'Abdul'],
#        ['103', 'Andrea'],
#        ['104', 'Venguard'],
#        ['105', 'John'],
#        ['106', 'Karaoke']], dtype='<U21')

# %%
transactions = np.array([
	[101,'Mohan',250.50,'2023-08-01'],
	[102,'Bob',150.00,'2023-08-02'],
	[103,'Fatima',300.75,'2023-08-01'],
	[104,'David',400.20,'2023-08-03'],
	[105,'Aryan',330.1,'2023-08-04']
])
a , b = np.hsplit(transactions,[2])

# %%
a
# Out:
# array([['101', 'Mohan'],
#        ['102', 'Bob'],
#        ['103', 'Fatima'],
#        ['104', 'David'],
#        ['105', 'Aryan']], dtype='<U32')

# %%
b
# Out:
# array([['250.5', '2023-08-01'],
#        ['150.0', '2023-08-02'],
#        ['300.75', '2023-08-01'],
#        ['400.2', '2023-08-03'],
#        ['330.1', '2023-08-04']], dtype='<U32')

# %%
a1 , b1 = np.vsplit(transactions,[3])

# %%
a1
# Out:
# array([['101', 'Mohan', '250.5', '2023-08-01'],
#        ['102', 'Bob', '150.0', '2023-08-02'],
#        ['103', 'Fatima', '300.75', '2023-08-01']], dtype='<U32')

# %%
b1
# Out:
# array([['104', 'David', '400.2', '2023-08-03'],
#        ['105', 'Aryan', '330.1', '2023-08-04']], dtype='<U32')

# %%
monthly_sales = np.array([30,33,35,28,42])

result = monthly_sales < 32
result
# Out:
# array([ True, False, False,  True, False])

# %%
monthly_sales[result]
# Out:
# array([30, 28])

# %%
monthly_sales.max()
# Out:
# np.int64(42)

# %%
index = np.argmax(monthly_sales)
index
# Out:
# np.int64(4)

# %%
tran = transactions[:,2].astype(float)

# %%
t_max = np.argmax(tran)
t_max
# Out:
# np.int64(3)

# %%
transactions[t_max]
# Out:
# array(['104', 'David', '400.2', '2023-08-03'], dtype='<U32')

# %%
transactions[transactions[:,0] == '102']
# Out:
# array([['102', 'Bob', '150.0', '2023-08-02']], dtype='<U32')
